# %% [markdown]
# <a href="https://colab.research.google.com/github/KanzulF/BangkitCapstone2022/blob/Machine-Learning/ModelMLFix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os 
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from keras.preprocessing import image
from google.colab import files
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from skimage.io import imread, imsave
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
#Import data dari gdrive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_dir = '/content/drive/MyDrive/DATA 5'
train_dir = os.path.join(file_dir, 'train')
valid_dir = os.path.join(file_dir, 'testing')
test_dir = os.path.join(file_dir, 'testing')

# %%
#Image data generator untuk dataset 
train_generator = ImageDataGenerator(rescale=1/255,
                                     shear_range=0.3,
                                     horizontal_flip=True,
                                     vertical_flip=True,
                                     rotation_range=60)

train_data = train_generator.flow_from_directory("/content/drive/MyDrive/DATA 5/train",
                                                 target_size=(224,224),
                                                 batch_size=22,
                                                 class_mode="categorical")

#Image data generator untuk validasi
validation_generator = ImageDataGenerator(rescale=1/255,
                                          shear_range=0.3,
                                          horizontal_flip=True,
                                          vertical_flip=True,
                                          rotation_range=60)

validation_data = validation_generator.flow_from_directory("/content/drive/MyDrive/DATA 5/testing",
                                                 target_size=(224,224),
                                                 batch_size=19,
                                                 class_mode="categorical")
# Out:
# Found 440 images belonging to 5 classes.
# Found 185 images belonging to 5 classes.

# %%
base_model = tf.keras.applications.InceptionResNetV2(input_shape = (224,224,3),
                                               include_top = False,
                                               weights ='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 4s 0us/step
# 219070464/219055592 [==============================] - 4s 0us/step

# %%
base_model.trainable= False

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if (logs.get('accuracy')>0.90):
      print("\n sudah mencapai 90% accuracy so cancelling training!")
      self.model.stop_training = True

# %%
#Setting Arsitektur CNN
model_image= tf.keras.models.Sequential([ 
base_model,
tf.keras.layers.GlobalAveragePooling2D(),
tf.keras.layers.Dense(128, activation='relu'),
tf.keras.layers.Dropout(0.5),
tf.keras.layers.Dense(5, activation='softmax')
])

# %%
from tensorflow.keras.optimizers import SGD
model_image.compile(loss='categorical_crossentropy',
                    optimizer= SGD(learning_rate=0.001, momentum=0.9),
                    metrics=['accuracy'])

# %%
filpath = "/content/drive/MyDrive/ModelMLFix.h5"
model_chekpoint = ModelCheckpoint(filpath,
                                  save_best_only=True,
                                  mode='max',
                                  monitor='val_accuracy')

# %%
#Training Model
callbacks = myCallback()
history = model_image.fit(train_data,
                          steps_per_epoch= 20,
                          epochs= 150,
                          validation_data=validation_data,
                          validation_steps = 10,
                          verbose= 2,
                          callbacks=[callbacks, model_chekpoint])
# Out:
# Epoch 1/150
# 20/20 - 28s - loss: 1.9843 - accuracy: 0.2818 - val_loss: 1.4291 - val_accuracy: 0.4162 - 28s/epoch - 1s/step
# Epoch 2/150
# 20/20 - 15s - loss: 1.4714 - accuracy: 0.3977 - val_loss: 1.3795 - val_accuracy: 0.4324 - 15s/epoch - 740ms/step
# Epoch 3/150
# 20/20 - 15s - loss: 1.1875 - accuracy: 0.5295 - val_loss: 1.2547 - val_accuracy: 0.4811 - 15s/epoch - 730ms/step
# Epoch 4/150
# 20/20 - 15s - loss: 1.3086 - accuracy: 0.5318 - val_loss: 1.2575 - val_accuracy: 0.5081 - 15s/epoch - 736ms/step
# Epoch 5/150
# 20/20 - 15s - loss: 1.1933 - accuracy: 0.5432 - val_loss: 1.2472 - val_accuracy: 0.5135 - 15s/epoch - 767ms/step
# Epoch 6/150
# 20/20 - 15s - loss: 1.1586 - accuracy: 0.5841 - val_loss: 1.1938 - val_accuracy: 0.5405 - 15s/epoch - 743ms/step
# Epoch 7/150
# 20/20 - 15s - loss: 1.0629 - accuracy: 0.5841 - val_loss: 1.0963 - val_accuracy: 0.6162 - 15s/epoch - 743ms/step
# Epoch 8/150
# 20/20 - 13s - loss: 1.0910 - accuracy: 0.5750 - val_loss: 1.1406 - val_accuracy: 0.5892 - 13s/epoch - 648ms/step
# Epoch 9/150
# 20/20 - 13s - loss: 1.0402 - accuracy: 0.5886 - val_loss: 1.1618 - val_accuracy: 0.5622 - 13s/epoch - 627ms/step
# Epoch 10/150
# 20/20 - 16s - loss: 1.0034 - accuracy: 0.6409 - val_loss: 1.1170 - val_accuracy: 0.6216 - 16s/epoch - 800ms/step
# Epoch 11/150
# 20/20 - 13s - loss: 0.9808 - accuracy: 0.6114 - val_loss: 1.1118 - val_accuracy: 0.5730 - 13s/epoch - 655ms/step
# Epoch 12/150
# 20/20 - 12s - loss: 0.9216 - accuracy: 0.6432 - val_loss: 1.1096 - val_accuracy: 0.5946 - 12s/epoch - 615ms/step
# Epoch 13/150
# 20/20 - 13s - loss: 1.0050 - accuracy: 0.6500 - val_loss: 1.1068 - val_accuracy: 0.6108 - 13s/epoch - 627ms/step
# Epoch 14/150
# 20/20 - 12s - loss: 0.9565 - accuracy: 0.6432 - val_loss: 1.1339 - val_accuracy: 0.5784 - 12s/epoch - 621ms/step
# Epoch 15/150
# 20/20 - 14s - loss: 0.9090 - accuracy: 0.6568 - val_loss: 1.1149 - val_accuracy: 0.5730 - 14s/epoch - 680ms/step
# Epoch 16/150
# 20/20 - 12s - loss: 0.9384 - accuracy: 0.6409 - val_loss: 1.0874 - val_accuracy: 0.6162 - 12s/epoch - 624ms/step
# Epoch 17/150
# 20/20 - 12s - loss: 0.8816 - accuracy: 0.6955 - val_loss: 1.0530 - val_accuracy: 0.5838 - 12s/epoch - 619ms/step
# Epoch 18/150
# 20/20 - 12s - loss: 0.9053 - accuracy: 0.6523 - val_loss: 1.0586 - val_accuracy: 0.5892 - 12s/epoch - 622ms/step
# Epoch 19/150
# 20/20 - 12s - loss: 0.8157 - accuracy: 0.7000 - val_loss: 1.0706 - val_accuracy: 0.6108 - 12s/epoch - 617ms/step
# Epoch 20/150
# 20/20 - 13s - loss: 0.8469 - accuracy: 0.6818 - val_loss: 1.0434 - val_accuracy: 0.6216 - 13s/epoch - 628ms/step
# Epoch 21/150
# 20/20 - 16s - loss: 0.9109 - accuracy: 0.6500 - val_loss: 1.0269 - val_accuracy: 0.6649 - 16s/epoch - 793ms/step
# Epoch 22/150
# 20/20 - 13s - loss: 0.8294 - accuracy: 0.6636 - val_loss: 1.0122 - val_accuracy: 0.6324 - 13s/epoch - 652ms/step
# Epoch 23/150
# 20/20 - 13s - loss: 0.8670 - accuracy: 0.6455 - val_loss: 1.0273 - val_accuracy: 0.6216 - 13s/epoch - 637ms/step
# Epoch 24/150
# 20/20 - 12s - loss: 0.8620 - accuracy: 0.6705 - val_loss: 1.0400 - val_accuracy: 0.6054 - 12s/epoch - 616ms/step
# Epoch 25/150
# 20/20 - 12s - loss: 0.8231 - accuracy: 0.6977 - val_loss: 1.0513 - val_accuracy: 0.5892 - 12s/epoch - 623ms/step
# Epoch 26/150
# 20/20 - 12s - loss: 0.7945 - accuracy: 0.7273 - val_loss: 0.9802 - val_accuracy: 0.6486 - 12s/epoch - 616ms/step
# Epoch 27/150
# 20/20 - 13s - loss: 0.8104 - accuracy: 0.7023 - val_loss: 1.0494 - val_accuracy: 0.5892 - 13s/epoch - 637ms/step
# Epoch 28/150
# 20/20 - 13s - loss: 0.8386 - accuracy: 0.7000 - val_loss: 1.0067 - val_accuracy: 0.6595 - 13s/epoch - 626ms/step
# Epoch 29/150
# 20/20 - 12s - loss: 0.7700 - accuracy: 0.7159 - val_loss: 0.9843 - val_accuracy: 0.6432 - 12s/epoch - 624ms/step
# Epoch 30/150
# 20/20 - 12s - loss: 0.8222 - accuracy: 0.6773 - val_loss: 1.0618 - val_accuracy: 0.6324 - 12s/epoch - 621ms/step
# Epoch 31/150
# 20/20 - 12s - loss: 0.7664 - accuracy: 0.7136 - val_loss: 1.0737 - val_accuracy: 0.6216 - 12s/epoch - 622ms/step
# Epoch 32/150
# 20/20 - 16s - loss: 0.7484 - accuracy: 0.7250 - val_loss: 1.0409 - val_accuracy: 0.6703 - 16s/epoch - 806ms/step
# Epoch 33/150
# 20/20 - 13s - loss: 0.8156 - accuracy: 0.6955 - val_loss: 1.0544 - val_accuracy: 0.6432 - 13s/epoch - 641ms/step
# Epoch 34/150
# 20/20 - 13s - loss: 0.7239 - accuracy: 0.7318 - val_loss: 1.0385 - val_accuracy: 0.6000 - 13s/epoch - 629ms/step
# Epoch 35/150
# 20/20 - 12s - loss: 0.7939 - accuracy: 0.7000 - val_loss: 1.0719 - val_accuracy: 0.6378 - 12s/epoch - 617ms/step
# Epoch 36/150
# 20/20 - 12s - loss: 0.7414 - accuracy: 0.7227 - val_loss: 0.9306 - val_accuracy: 0.6649 - 12s/epoch - 617ms/step
# Epoch 37/150
# 20/20 - 16s - loss: 0.7118 - accuracy: 0.7318 - val_loss: 0.9505 - val_accuracy: 0.6757 - 16s/epoch - 804ms/step
# Epoch 38/150
# 20/20 - 13s - loss: 0.6929 - accuracy: 0.7409 - val_loss: 0.9899 - val_accuracy: 0.6649 - 13s/epoch - 639ms/step
# Epoch 39/150
# 20/20 - 13s - loss: 0.7164 - accuracy: 0.7364 - val_loss: 0.9754 - val_accuracy: 0.6541 - 13s/epoch - 656ms/step
# Epoch 40/150
# 20/20 - 13s - loss: 0.7368 - accuracy: 0.7273 - val_loss: 0.9713 - val_accuracy: 0.6703 - 13s/epoch - 657ms/step
# Epoch 41/150
# 20/20 - 13s - loss: 0.7156 - accuracy: 0.7364 - val_loss: 0.9657 - val_accuracy: 0.6541 - 13s/epoch - 629ms/step
# Epoch 42/150
# 20/20 - 16s - loss: 0.7398 - accuracy: 0.7068 - val_loss: 1.0045 - val_accuracy: 0.6811 - 16s/epoch - 800ms/step
# Epoch 43/150
# 20/20 - 13s - loss: 0.6657 - accuracy: 0.7364 - val_loss: 0.9768 - val_accuracy: 0.6541 - 13s/epoch - 647ms/step
# Epoch 44/150
# 20/20 - 12s - loss: 0.6469 - accuracy: 0.7773 - val_loss: 1.0087 - val_accuracy: 0.6595 - 12s/epoch - 625ms/step
# Epoch 45/150
# 20/20 - 13s - loss: 0.6670 - accuracy: 0.7545 - val_loss: 1.1054 - val_accuracy: 0.6432 - 13s/epoch - 630ms/step
# Epoch 46/150
# 20/20 - 12s - loss: 0.6539 - accuracy: 0.7750 - val_loss: 1.0144 - val_accuracy: 0.6757 - 12s/epoch - 620ms/step
# Epoch 47/150
# 20/20 - 12s - loss: 0.6476 - accuracy: 0.7591 - val_loss: 0.9457 - val_accuracy: 0.6270 - 12s/epoch - 616ms/step
# Epoch 48/150
# 20/20 - 12s - loss: 0.6324 - accuracy: 0.7705 - val_loss: 0.9515 - val_accuracy: 0.6541 - 12s/epoch - 618ms/step
# Epoch 49/150
# 20/20 - 16s - loss: 0.6262 - accuracy: 0.7705 - val_loss: 1.0191 - val_accuracy: 0.6919 - 16s/epoch - 796ms/step
# Epoch 50/150
# 20/20 - 17s - loss: 0.6400 - accuracy: 0.7477 - val_loss: 0.9380 - val_accuracy: 0.7081 - 17s/epoch - 874ms/step
# Epoch 51/150
# 20/20 - 13s - loss: 0.6666 - accuracy: 0.7523 - val_loss: 0.9406 - val_accuracy: 0.6486 - 13s/epoch - 639ms/step
# Epoch 52/150
# 20/20 - 13s - loss: 0.6516 - accuracy: 0.7386 - val_loss: 1.0390 - val_accuracy: 0.6432 - 13s/epoch - 630ms/step
# Epoch 53/150
# 20/20 - 12s - loss: 0.6744 - accuracy: 0.7364 - val_loss: 0.9044 - val_accuracy: 0.6811 - 12s/epoch - 625ms/step
# Epoch 54/150
# 20/20 - 13s - loss: 0.6281 - accuracy: 0.7614 - val_loss: 0.9767 - val_accuracy: 0.6595 - 13s/epoch - 629ms/step
# Epoch 55/150
# 20/20 - 12s - loss: 0.5731 - accuracy: 0.7818 - val_loss: 1.0032 - val_accuracy: 0.6432 - 12s/epoch - 621ms/step
# Epoch 56/150
# 20/20 - 12s - loss: 0.6499 - accuracy: 0.7705 - val_loss: 0.9600 - val_accuracy: 0.6757 - 12s/epoch - 620ms/step
# Epoch 57/150
# 20/20 - 12s - loss: 0.5922 - accuracy: 0.7568 - val_loss: 1.0012 - val_accuracy: 0.6757 - 12s/epoch - 622ms/step
# Epoch 58/150
# 20/20 - 12s - loss: 0.6543 - accuracy: 0.7636 - val_loss: 0.9980 - val_accuracy: 0.6919 - 12s/epoch - 621ms/step
# Epoch 59/150
# 20/20 - 12s - loss: 0.6049 - accuracy: 0.7773 - val_loss: 0.8986 - val_accuracy: 0.6649 - 12s/epoch - 623ms/step
# Epoch 60/150
# 20/20 - 12s - loss: 0.6031 - accuracy: 0.7523 - val_loss: 0.9681 - val_accuracy: 0.6865 - 12s/epoch - 618ms/step
# Epoch 61/150
# 20/20 - 13s - loss: 0.5633 - accuracy: 0.7705 - val_loss: 1.0531 - val_accuracy: 0.6595 - 13s/epoch - 626ms/step
# Epoch 62/150
# 20/20 - 12s - loss: 0.5567 - accuracy: 0.7886 - val_loss: 0.9804 - val_accuracy: 0.6973 - 12s/epoch - 620ms/step
# Epoch 63/150
# 20/20 - 13s - loss: 0.5668 - accuracy: 0.8000 - val_loss: 1.0110 - val_accuracy: 0.6378 - 13s/epoch - 632ms/step
# Epoch 64/150
# 20/20 - 13s - loss: 0.5496 - accuracy: 0.7909 - val_loss: 0.9176 - val_accuracy: 0.6757 - 13s/epoch - 667ms/step
# Epoch 65/150
# 20/20 - 12s - loss: 0.5836 - accuracy: 0.7682 - val_loss: 0.9795 - val_accuracy: 0.6595 - 12s/epoch - 624ms/step
# Epoch 66/150
# 20/20 - 12s - loss: 0.6103 - accuracy: 0.7636 - val_loss: 0.9577 - val_accuracy: 0.6865 - 12s/epoch - 620ms/step
# Epoch 67/150
# 20/20 - 12s - loss: 0.5978 - accuracy: 0.7750 - val_loss: 0.9491 - val_accuracy: 0.6865 - 12s/epoch - 615ms/step
# Epoch 68/150
# 20/20 - 13s - loss: 0.5537 - accuracy: 0.7977 - val_loss: 1.0230 - val_accuracy: 0.6595 - 13s/epoch - 626ms/step
# Epoch 69/150
# 20/20 - 17s - loss: 0.5538 - accuracy: 0.7932 - val_loss: 0.9811 - val_accuracy: 0.7135 - 17s/epoch - 826ms/step
# Epoch 70/150
# 20/20 - 13s - loss: 0.5889 - accuracy: 0.7864 - val_loss: 0.9784 - val_accuracy: 0.7027 - 13s/epoch - 647ms/step
# Epoch 71/150
# 20/20 - 12s - loss: 0.5214 - accuracy: 0.8023 - val_loss: 0.9788 - val_accuracy: 0.6703 - 12s/epoch - 615ms/step
# Epoch 72/150
# 20/20 - 12s - loss: 0.5726 - accuracy: 0.8000 - val_loss: 0.9818 - val_accuracy: 0.6757 - 12s/epoch - 617ms/step
# Epoch 73/150
# 20/20 - 12s - loss: 0.5295 - accuracy: 0.8205 - val_loss: 0.9724 - val_accuracy: 0.6811 - 12s/epoch - 624ms/step
# Epoch 74/150
# 20/20 - 13s - loss: 0.6095 - accuracy: 0.7932 - val_loss: 0.9651 - val_accuracy: 0.6865 - 13s/epoch - 634ms/step
# Epoch 75/150
# 20/20 - 13s - loss: 0.5437 - accuracy: 0.8023 - val_loss: 0.9053 - val_accuracy: 0.7027 - 13s/epoch - 626ms/step
# Epoch 76/150
# 20/20 - 12s - loss: 0.5383 - accuracy: 0.7795 - val_loss: 0.9274 - val_accuracy: 0.6757 - 12s/epoch - 622ms/step
# Epoch 77/150
# 20/20 - 12s - loss: 0.5846 - accuracy: 0.7977 - val_loss: 0.9498 - val_accuracy: 0.6649 - 12s/epoch - 622ms/step
# Epoch 78/150
# 20/20 - 13s - loss: 0.5372 - accuracy: 0.7955 - val_loss: 0.9893 - val_accuracy: 0.6811 - 13s/epoch - 632ms/step
# Epoch 79/150
# 20/20 - 12s - loss: 0.5332 - accuracy: 0.8023 - val_loss: 1.0186 - val_accuracy: 0.6865 - 12s/epoch - 617ms/step
# Epoch 80/150
# 20/20 - 12s - loss: 0.5154 - accuracy: 0.8273 - val_loss: 1.0592 - val_accuracy: 0.6324 - 12s/epoch - 623ms/step
# Epoch 81/150
# 20/20 - 13s - loss: 0.5589 - accuracy: 0.7886 - val_loss: 0.9412 - val_accuracy: 0.7027 - 13s/epoch - 626ms/step
# Epoch 82/150
# 20/20 - 13s - loss: 0.5542 - accuracy: 0.7818 - val_loss: 0.9098 - val_accuracy: 0.6811 - 13s/epoch - 625ms/step
# Epoch 83/150
# 20/20 - 12s - loss: 0.5469 - accuracy: 0.7932 - val_loss: 0.9343 - val_accuracy: 0.6919 - 12s/epoch - 617ms/step
# Epoch 84/150
# 20/20 - 12s - loss: 0.4959 - accuracy: 0.8295 - val_loss: 1.0318 - val_accuracy: 0.6486 - 12s/epoch - 621ms/step
# Epoch 85/150
# 20/20 - 12s - loss: 0.4939 - accuracy: 0.8045 - val_loss: 0.9566 - val_accuracy: 0.6757 - 12s/epoch - 622ms/step
# Epoch 86/150
# 20/20 - 12s - loss: 0.5289 - accuracy: 0.8068 - val_loss: 0.8986 - val_accuracy: 0.6865 - 12s/epoch - 619ms/step
# Epoch 87/150
# 20/20 - 12s - loss: 0.4979 - accuracy: 0.8250 - val_loss: 0.9655 - val_accuracy: 0.6811 - 12s/epoch - 624ms/step
# Epoch 88/150
# 20/20 - 13s - loss: 0.5042 - accuracy: 0.8023 - val_loss: 0.9335 - val_accuracy: 0.7081 - 13s/epoch - 634ms/step
# Epoch 89/150
# 20/20 - 14s - loss: 0.5450 - accuracy: 0.7886 - val_loss: 1.0558 - val_accuracy: 0.6432 - 14s/epoch - 687ms/step
# Epoch 90/150
# 20/20 - 12s - loss: 0.5326 - accuracy: 0.7932 - val_loss: 1.0311 - val_accuracy: 0.6811 - 12s/epoch - 621ms/step
# Epoch 91/150
# 20/20 - 12s - loss: 0.5322 - accuracy: 0.8000 - val_loss: 0.8909 - val_accuracy: 0.7135 - 12s/epoch - 621ms/step
# Epoch 92/150
# 20/20 - 12s - loss: 0.4886 - accuracy: 0.8227 - val_loss: 0.9550 - val_accuracy: 0.6486 - 12s/epoch - 624ms/step
# Epoch 93/150
# 20/20 - 13s - loss: 0.5005 - accuracy: 0.8182 - val_loss: 0.9696 - val_accuracy: 0.6919 - 13s/epoch - 629ms/step
# Epoch 94/150
# 20/20 - 12s - loss: 0.4778 - accuracy: 0.8318 - val_loss: 0.9134 - val_accuracy: 0.7081 - 12s/epoch - 625ms/step
# Epoch 95/150
# 20/20 - 12s - loss: 0.5075 - accuracy: 0.7977 - val_loss: 1.0391 - val_accuracy: 0.6649 - 12s/epoch - 619ms/step
# Epoch 96/150
# 20/20 - 13s - loss: 0.5369 - accuracy: 0.7886 - val_loss: 0.8879 - val_accuracy: 0.6973 - 13s/epoch - 630ms/step
# Epoch 97/150
# 20/20 - 13s - loss: 0.4800 - accuracy: 0.8386 - val_loss: 0.9488 - val_accuracy: 0.7081 - 13s/epoch - 640ms/step
# Epoch 98/150
# 20/20 - 13s - loss: 0.4971 - accuracy: 0.8250 - val_loss: 0.9251 - val_accuracy: 0.6865 - 13s/epoch - 628ms/step
# Epoch 99/150
# 20/20 - 12s - loss: 0.4624 - accuracy: 0.8432 - val_loss: 0.9789 - val_accuracy: 0.6703 - 12s/epoch - 616ms/step
# Epoch 100/150
# 20/20 - 12s - loss: 0.4691 - accuracy: 0.8341 - val_loss: 1.0699 - val_accuracy: 0.6649 - 12s/epoch - 620ms/step
# Epoch 101/150
# 20/20 - 12s - loss: 0.5206 - accuracy: 0.8250 - val_loss: 0.9344 - val_accuracy: 0.6865 - 12s/epoch - 619ms/step
# Epoch 102/150
# 20/20 - 12s - loss: 0.4808 - accuracy: 0.8295 - val_loss: 1.0644 - val_accuracy: 0.6324 - 12s/epoch - 615ms/step
# Epoch 103/150
# 20/20 - 13s - loss: 0.5034 - accuracy: 0.8318 - val_loss: 1.0116 - val_accuracy: 0.6703 - 13s/epoch - 626ms/step
# Epoch 104/150
# 20/20 - 13s - loss: 0.4968 - accuracy: 0.8068 - val_loss: 0.9329 - val_accuracy: 0.7135 - 13s/epoch - 637ms/step
# Epoch 105/150
# 20/20 - 13s - loss: 0.4771 - accuracy: 0.8068 - val_loss: 0.9674 - val_accuracy: 0.6595 - 13s/epoch - 638ms/step
# Epoch 106/150
# 20/20 - 13s - loss: 0.4456 - accuracy: 0.8409 - val_loss: 1.0001 - val_accuracy: 0.6865 - 13s/epoch - 628ms/step
# Epoch 107/150
# 20/20 - 12s - loss: 0.4646 - accuracy: 0.8318 - val_loss: 1.0239 - val_accuracy: 0.6486 - 12s/epoch - 623ms/step
# Epoch 108/150
# 20/20 - 13s - loss: 0.4508 - accuracy: 0.8250 - val_loss: 0.9791 - val_accuracy: 0.7027 - 13s/epoch - 637ms/step
# Epoch 109/150
# 20/20 - 13s - loss: 0.4872 - accuracy: 0.8114 - val_loss: 1.0297 - val_accuracy: 0.6432 - 13s/epoch - 628ms/step
# Epoch 110/150
# 20/20 - 12s - loss: 0.4506 - accuracy: 0.8386 - val_loss: 0.8766 - val_accuracy: 0.7027 - 12s/epoch - 621ms/step
# Epoch 111/150
# 20/20 - 13s - loss: 0.4840 - accuracy: 0.8091 - val_loss: 1.0469 - val_accuracy: 0.6919 - 13s/epoch - 663ms/step
# Epoch 112/150
# 20/20 - 13s - loss: 0.4442 - accuracy: 0.8455 - val_loss: 1.0246 - val_accuracy: 0.6649 - 13s/epoch - 636ms/step
# Epoch 113/150
# 20/20 - 17s - loss: 0.4401 - accuracy: 0.8523 - val_loss: 0.8232 - val_accuracy: 0.7514 - 17s/epoch - 870ms/step
# Epoch 114/150
# 20/20 - 13s - loss: 0.4657 - accuracy: 0.8386 - val_loss: 0.9588 - val_accuracy: 0.6865 - 13s/epoch - 643ms/step
# Epoch 115/150
# 20/20 - 12s - loss: 0.4519 - accuracy: 0.8341 - val_loss: 0.9229 - val_accuracy: 0.6919 - 12s/epoch - 625ms/step
# Epoch 116/150
# 20/20 - 13s - loss: 0.5005 - accuracy: 0.8182 - val_loss: 0.9431 - val_accuracy: 0.6649 - 13s/epoch - 637ms/step
# Epoch 117/150
# 20/20 - 13s - loss: 0.4257 - accuracy: 0.8500 - val_loss: 1.0302 - val_accuracy: 0.6865 - 13s/epoch - 630ms/step
# Epoch 118/150
# 20/20 - 13s - loss: 0.4022 - accuracy: 0.8523 - val_loss: 0.9681 - val_accuracy: 0.7027 - 13s/epoch - 633ms/step
# Epoch 119/150
# 20/20 - 13s - loss: 0.4679 - accuracy: 0.8159 - val_loss: 0.9509 - val_accuracy: 0.6919 - 13s/epoch - 633ms/step
# Epoch 120/150
# 20/20 - 13s - loss: 0.4218 - accuracy: 0.8364 - val_loss: 1.0040 - val_accuracy: 0.6703 - 13s/epoch - 635ms/step
# Epoch 121/150
# 20/20 - 13s - loss: 0.4360 - accuracy: 0.8455 - val_loss: 0.9579 - val_accuracy: 0.7135 - 13s/epoch - 638ms/step
# Epoch 122/150
# 20/20 - 13s - loss: 0.4058 - accuracy: 0.8455 - val_loss: 1.1079 - val_accuracy: 0.6432 - 13s/epoch - 641ms/step
# Epoch 123/150
# 20/20 - 13s - loss: 0.4302 - accuracy: 0.8250 - val_loss: 0.9307 - val_accuracy: 0.6973 - 13s/epoch - 635ms/step
# Epoch 124/150
# 20/20 - 13s - loss: 0.4340 - accuracy: 0.8273 - val_loss: 0.9442 - val_accuracy: 0.6595 - 13s/epoch - 628ms/step
# Epoch 125/150
# 20/20 - 13s - loss: 0.4288 - accuracy: 0.8409 - val_loss: 0.9787 - val_accuracy: 0.7297 - 13s/epoch - 638ms/step
# Epoch 126/150
# 20/20 - 13s - loss: 0.4340 - accuracy: 0.8500 - val_loss: 0.9592 - val_accuracy: 0.6865 - 13s/epoch - 644ms/step
# Epoch 127/150
# 20/20 - 13s - loss: 0.4087 - accuracy: 0.8477 - val_loss: 0.9525 - val_accuracy: 0.7243 - 13s/epoch - 636ms/step
# Epoch 128/150
# 20/20 - 13s - loss: 0.4175 - accuracy: 0.8341 - val_loss: 0.9975 - val_accuracy: 0.6865 - 13s/epoch - 636ms/step
# Epoch 129/150
# 20/20 - 13s - loss: 0.4483 - accuracy: 0.8364 - val_loss: 0.9781 - val_accuracy: 0.6757 - 13s/epoch - 650ms/step
# Epoch 130/150
# 20/20 - 13s - loss: 0.3848 - accuracy: 0.8659 - val_loss: 1.0142 - val_accuracy: 0.6703 - 13s/epoch - 643ms/step
# Epoch 131/150
# 20/20 - 13s - loss: 0.4481 - accuracy: 0.8341 - val_loss: 0.9600 - val_accuracy: 0.6432 - 13s/epoch - 630ms/step
# Epoch 132/150
# 20/20 - 13s - loss: 0.4409 - accuracy: 0.8341 - val_loss: 1.0160 - val_accuracy: 0.6757 - 13s/epoch - 639ms/step
# Epoch 133/150
# 20/20 - 13s - loss: 0.3903 - accuracy: 0.8591 - val_loss: 0.9067 - val_accuracy: 0.7027 - 13s/epoch - 645ms/step
# Epoch 134/150
# 20/20 - 13s - loss: 0.4025 - accuracy: 0.8523 - val_loss: 0.9588 - val_accuracy: 0.7027 - 13s/epoch - 642ms/step
# Epoch 135/150
# 20/20 - 13s - loss: 0.4978 - accuracy: 0.8136 - val_loss: 0.9812 - val_accuracy: 0.6811 - 13s/epoch - 634ms/step
# Epoch 136/150
# 20/20 - 13s - loss: 0.4026 - accuracy: 0.8614 - val_loss: 0.9860 - val_accuracy: 0.6973 - 13s/epoch - 645ms/step
# Epoch 137/150
# 20/20 - 12s - loss: 0.4072 - accuracy: 0.8250 - val_loss: 1.0552 - val_accuracy: 0.6703 - 12s/epoch - 613ms/step
# Epoch 138/150
# 20/20 - 12s - loss: 0.4303 - accuracy: 0.8523 - val_loss: 0.9724 - val_accuracy: 0.6865 - 12s/epoch - 608ms/step
# Epoch 139/150
# 20/20 - 12s - loss: 0.3948 - accuracy: 0.8636 - val_loss: 1.0314 - val_accuracy: 0.6757 - 12s/epoch - 609ms/step
# Epoch 140/150
# 20/20 - 12s - loss: 0.3852 - accuracy: 0.8591 - val_loss: 1.0586 - val_accuracy: 0.6541 - 12s/epoch - 610ms/step
# Epoch 141/150
# 20/20 - 12s - loss: 0.3738 - accuracy: 0.8523 - val_loss: 0.9777 - val_accuracy: 0.6162 - 12s/epoch - 614ms/step
# Epoch 142/150
# 20/20 - 12s - loss: 0.3644 - accuracy: 0.8750 - val_loss: 1.0225 - val_accuracy: 0.6919 - 12s/epoch - 611ms/step
# Epoch 143/150
# 20/20 - 12s - loss: 0.4226 - accuracy: 0.8318 - val_loss: 0.9749 - val_accuracy: 0.6595 - 12s/epoch - 620ms/step
# Epoch 144/150
# 20/20 - 12s - loss: 0.3988 - accuracy: 0.8364 - val_loss: 0.9420 - val_accuracy: 0.6919 - 12s/epoch - 615ms/step
# Epoch 145/150
# 20/20 - 13s - loss: 0.3942 - accuracy: 0.8545 - val_loss: 0.9871 - val_accuracy: 0.6703 - 13s/epoch - 674ms/step
# Epoch 146/150
# 20/20 - 12s - loss: 0.4406 - accuracy: 0.8295 - val_loss: 0.8561 - val_accuracy: 0.7189 - 12s/epoch - 603ms/step
# Epoch 147/150
# 20/20 - 12s - loss: 0.3705 - accuracy: 0.8795 - val_loss: 1.0022 - val_accuracy: 0.7135 - 12s/epoch - 599ms/step
# Epoch 148/150
# 20/20 - 12s - loss: 0.4425 - accuracy: 0.8205 - val_loss: 1.0096 - val_accuracy: 0.6649 - 12s/epoch - 601ms/step
# Epoch 149/150
# 20/20 - 12s - loss: 0.3494 - accuracy: 0.8750 - val_loss: 0.9877 - val_accuracy: 0.6811 - 12s/epoch - 606ms/step
# Epoch 150/150
# 20/20 - 12s - loss: 0.3937 - accuracy: 0.8523 - val_loss: 1.0483 - val_accuracy: 0.7135 - 12s/epoch - 600ms/step

# %%
#Plot Training

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training Model', 'Validation Model'], loc='upper right')
plt.title('Nilai validasi loss pada tiap epoch')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training Model', 'Validation Model'], loc='upper right')
plt.title('Nilai akurasi pada tiap epoch')
plt.show()

# %% [markdown]
# ### **Testing Model Prediction**

# %%
model = load_model("/content/drive/MyDrive/ModelMLFix.h5")

# %%
labels = train_data.class_indices
labels = dict((v,k) for k,v in labels.items())

print(labels)
# Out:
# {0: 'Acne', 1: 'Actinic Keratosis', 2: 'Basal Cell Carcinoma', 3: 'Eczemaa', 4: 'Rosacea'}

# %%
#Testing
from keras.preprocessing import image
from google.colab import files

uploade = files.upload()

for ft in uploade.keys():

  pathtest = ft
  img = image.load_img(pathtest, target_size= (224, 224))
  imagplot = plt.imshow(img)
  xtest = image.img_to_array(img)
  xtest = np.expand_dims(xtest, axis=0)

  file_image = np.vstack([xtest])
  prediction_class = model_image.predict(file_image, batch_size=10)
  print(ft)

  output = prediction_class[0].argmax()
  print("The image is classified as:",labels[output])

  break
# Out:
#      <input type="file" id="files-b34d73ff-a3e1-4506-8c52-35d054c1932d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b34d73ff-a3e1-4506-8c52-35d054c1932d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving eczema31.jpg to eczema31.jpg
# eczema31.jpg
# The image is classified as: Eczemaa
