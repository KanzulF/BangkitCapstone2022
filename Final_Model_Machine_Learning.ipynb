# %%
import os 
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from keras.preprocessing import image
from google.colab import files
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from skimage.io import imread, imsave
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import matplotlib.image as img
import pathlib

# %%
#Import data dari gdrive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_dir = '/content/drive/MyDrive/DATA 5'
train_dir = os.path.join(file_dir, 'train')
valid_dir = os.path.join(file_dir, 'testing')
test_dir = os.path.join(file_dir, 'testing')

# %%
#Image data generator untuk dataset 
train_generator = ImageDataGenerator(rescale=1/255,
                                     shear_range=0.3,
                                     horizontal_flip=True,
                                     vertical_flip=True,
                                     rotation_range=60)

train_data = train_generator.flow_from_directory("/content/drive/MyDrive/DATA 5/train",
                                                 target_size=(224,224),
                                                 batch_size=22,
                                                 class_mode="categorical")

#Image data generator untuk validasi
validation_generator = ImageDataGenerator(rescale=1/255,
                                          shear_range=0.3,
                                          horizontal_flip=True,
                                          vertical_flip=True,
                                          rotation_range=60)

validation_data = validation_generator.flow_from_directory("/content/drive/MyDrive/DATA 5/testing",
                                                 target_size=(224,224),
                                                 batch_size=19,
                                                 class_mode="categorical")
# Out:
# Found 440 images belonging to 5 classes.
# Found 185 images belonging to 5 classes.

# %%
base_model = tf.keras.applications.InceptionResNetV2(input_shape = (224,224,3),
                                               include_top = False,
                                               weights ='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# 219070464/219055592 [==============================] - 1s 0us/step

# %%
base_model.trainable= False

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if (logs.get('accuracy')>0.90):
      print("\n sudah mencapai 90% accuracy so cancelling training!")
      self.model.stop_training = True

# %%
#Setting Arsitektur CNN
model_image= tf.keras.models.Sequential([ 
base_model,
tf.keras.layers.GlobalAveragePooling2D(),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(128, activation='relu'),
tf.keras.layers.Dropout(0.5),
tf.keras.layers.Dense(5, activation='softmax')
])

# %%
from tensorflow.keras.optimizers import SGD
model_image.compile(loss='categorical_crossentropy',
                    optimizer= SGD(learning_rate=0.001, momentum=0.9),
                    metrics=['accuracy'])

# %%
filpath = "/content/drive/MyDrive/FinalModelML.h5"
model_chekpoint = ModelCheckpoint(filpath,
                                  save_best_only=True,
                                  mode='max',
                                  monitor='val_accuracy')

# %%
#Training Model
callbacks = myCallback()
history = model_image.fit(train_data,
                          steps_per_epoch= 20,
                          epochs= 150,
                          validation_data=validation_data,
                          validation_steps = 10,
                          verbose= 2,
                          callbacks=[callbacks, model_chekpoint])
# Out:
# Epoch 1/150
# 20/20 - 148s - loss: 1.8773 - accuracy: 0.2523 - val_loss: 1.4104 - val_accuracy: 0.4324 - 148s/epoch - 7s/step
# Epoch 2/150
# 20/20 - 18s - loss: 1.4357 - accuracy: 0.3795 - val_loss: 1.3305 - val_accuracy: 0.4703 - 18s/epoch - 881ms/step
# Epoch 3/150
# 20/20 - 17s - loss: 1.3387 - accuracy: 0.4545 - val_loss: 1.2844 - val_accuracy: 0.4919 - 17s/epoch - 838ms/step
# Epoch 4/150
# 20/20 - 17s - loss: 1.2540 - accuracy: 0.5295 - val_loss: 1.2183 - val_accuracy: 0.5081 - 17s/epoch - 833ms/step
# Epoch 5/150
# 20/20 - 17s - loss: 1.2477 - accuracy: 0.5045 - val_loss: 1.2160 - val_accuracy: 0.5189 - 17s/epoch - 829ms/step
# Epoch 6/150
# 20/20 - 17s - loss: 1.1398 - accuracy: 0.5932 - val_loss: 1.1687 - val_accuracy: 0.5297 - 17s/epoch - 840ms/step
# Epoch 7/150
# 20/20 - 17s - loss: 1.1291 - accuracy: 0.5727 - val_loss: 1.1820 - val_accuracy: 0.5459 - 17s/epoch - 847ms/step
# Epoch 8/150
# 20/20 - 14s - loss: 1.0964 - accuracy: 0.5932 - val_loss: 1.1722 - val_accuracy: 0.5459 - 14s/epoch - 687ms/step
# Epoch 9/150
# 20/20 - 16s - loss: 1.0665 - accuracy: 0.5932 - val_loss: 1.1553 - val_accuracy: 0.5514 - 16s/epoch - 816ms/step
# Epoch 10/150
# 20/20 - 17s - loss: 1.0031 - accuracy: 0.6250 - val_loss: 1.1986 - val_accuracy: 0.5784 - 17s/epoch - 828ms/step
# Epoch 11/150
# 20/20 - 18s - loss: 1.0113 - accuracy: 0.5955 - val_loss: 1.0737 - val_accuracy: 0.6054 - 18s/epoch - 904ms/step
# Epoch 12/150
# 20/20 - 14s - loss: 0.9929 - accuracy: 0.6159 - val_loss: 1.1578 - val_accuracy: 0.6054 - 14s/epoch - 710ms/step
# Epoch 13/150
# 20/20 - 13s - loss: 0.9769 - accuracy: 0.6182 - val_loss: 1.1569 - val_accuracy: 0.5946 - 13s/epoch - 670ms/step
# Epoch 14/150
# 20/20 - 16s - loss: 0.9822 - accuracy: 0.6386 - val_loss: 1.0380 - val_accuracy: 0.6432 - 16s/epoch - 816ms/step
# Epoch 15/150
# 20/20 - 14s - loss: 0.9733 - accuracy: 0.6250 - val_loss: 1.0719 - val_accuracy: 0.6108 - 14s/epoch - 689ms/step
# Epoch 16/150
# 20/20 - 13s - loss: 0.9318 - accuracy: 0.6568 - val_loss: 1.0153 - val_accuracy: 0.6378 - 13s/epoch - 664ms/step
# Epoch 17/150
# 20/20 - 13s - loss: 0.9317 - accuracy: 0.6545 - val_loss: 1.0642 - val_accuracy: 0.6324 - 13s/epoch - 664ms/step
# Epoch 18/150
# 20/20 - 16s - loss: 0.8394 - accuracy: 0.6750 - val_loss: 1.0259 - val_accuracy: 0.6595 - 16s/epoch - 820ms/step
# Epoch 19/150
# 20/20 - 14s - loss: 0.9420 - accuracy: 0.6500 - val_loss: 0.9886 - val_accuracy: 0.6216 - 14s/epoch - 702ms/step
# Epoch 20/150
# 20/20 - 15s - loss: 0.9075 - accuracy: 0.6614 - val_loss: 1.0906 - val_accuracy: 0.6378 - 15s/epoch - 735ms/step
# Epoch 21/150
# 20/20 - 13s - loss: 0.8327 - accuracy: 0.7000 - val_loss: 1.0296 - val_accuracy: 0.6270 - 13s/epoch - 672ms/step
# Epoch 22/150
# 20/20 - 13s - loss: 0.8602 - accuracy: 0.6727 - val_loss: 1.0202 - val_accuracy: 0.6486 - 13s/epoch - 670ms/step
# Epoch 23/150
# 20/20 - 16s - loss: 0.8422 - accuracy: 0.6932 - val_loss: 1.0320 - val_accuracy: 0.6703 - 16s/epoch - 822ms/step
# Epoch 24/150
# 20/20 - 14s - loss: 0.8364 - accuracy: 0.6773 - val_loss: 0.9948 - val_accuracy: 0.6432 - 14s/epoch - 719ms/step
# Epoch 25/150
# 20/20 - 17s - loss: 0.8451 - accuracy: 0.6750 - val_loss: 0.9808 - val_accuracy: 0.6757 - 17s/epoch - 828ms/step
# Epoch 26/150
# 20/20 - 14s - loss: 0.8387 - accuracy: 0.6909 - val_loss: 1.0233 - val_accuracy: 0.6216 - 14s/epoch - 706ms/step
# Epoch 27/150
# 20/20 - 13s - loss: 0.7950 - accuracy: 0.6955 - val_loss: 1.0543 - val_accuracy: 0.6432 - 13s/epoch - 668ms/step
# Epoch 28/150
# 20/20 - 14s - loss: 0.8010 - accuracy: 0.6841 - val_loss: 0.9725 - val_accuracy: 0.6541 - 14s/epoch - 678ms/step
# Epoch 29/150
# 20/20 - 13s - loss: 0.7893 - accuracy: 0.7136 - val_loss: 1.0102 - val_accuracy: 0.6216 - 13s/epoch - 668ms/step
# Epoch 30/150
# 20/20 - 17s - loss: 0.7582 - accuracy: 0.7159 - val_loss: 1.0052 - val_accuracy: 0.6865 - 17s/epoch - 870ms/step
# Epoch 31/150
# 20/20 - 14s - loss: 0.7450 - accuracy: 0.7136 - val_loss: 0.9977 - val_accuracy: 0.6649 - 14s/epoch - 695ms/step
# Epoch 32/150
# 20/20 - 13s - loss: 0.7456 - accuracy: 0.7386 - val_loss: 0.9737 - val_accuracy: 0.6432 - 13s/epoch - 665ms/step
# Epoch 33/150
# 20/20 - 13s - loss: 0.7310 - accuracy: 0.7227 - val_loss: 0.9749 - val_accuracy: 0.6703 - 13s/epoch - 665ms/step
# Epoch 34/150
# 20/20 - 16s - loss: 0.7685 - accuracy: 0.7114 - val_loss: 0.9447 - val_accuracy: 0.7027 - 16s/epoch - 799ms/step
# Epoch 35/150
# 20/20 - 14s - loss: 0.7446 - accuracy: 0.7159 - val_loss: 0.9277 - val_accuracy: 0.6703 - 14s/epoch - 700ms/step
# Epoch 36/150
# 20/20 - 13s - loss: 0.7559 - accuracy: 0.7091 - val_loss: 0.9070 - val_accuracy: 0.6811 - 13s/epoch - 667ms/step
# Epoch 37/150
# 20/20 - 13s - loss: 0.6932 - accuracy: 0.7455 - val_loss: 1.0167 - val_accuracy: 0.6811 - 13s/epoch - 664ms/step
# Epoch 38/150
# 20/20 - 15s - loss: 0.7252 - accuracy: 0.7341 - val_loss: 0.9617 - val_accuracy: 0.6703 - 15s/epoch - 729ms/step
# Epoch 39/150
# 20/20 - 13s - loss: 0.6792 - accuracy: 0.7477 - val_loss: 0.9594 - val_accuracy: 0.6378 - 13s/epoch - 662ms/step
# Epoch 40/150
# 20/20 - 13s - loss: 0.6857 - accuracy: 0.7523 - val_loss: 0.9322 - val_accuracy: 0.6919 - 13s/epoch - 660ms/step
# Epoch 41/150
# 20/20 - 13s - loss: 0.6984 - accuracy: 0.7136 - val_loss: 0.9246 - val_accuracy: 0.6595 - 13s/epoch - 665ms/step
# Epoch 42/150
# 20/20 - 13s - loss: 0.6406 - accuracy: 0.7659 - val_loss: 0.9314 - val_accuracy: 0.6865 - 13s/epoch - 664ms/step
# Epoch 43/150
# 20/20 - 13s - loss: 0.6490 - accuracy: 0.7432 - val_loss: 0.9512 - val_accuracy: 0.6595 - 13s/epoch - 671ms/step
# Epoch 44/150
# 20/20 - 13s - loss: 0.6393 - accuracy: 0.7636 - val_loss: 0.9544 - val_accuracy: 0.6649 - 13s/epoch - 663ms/step
# Epoch 45/150
# 20/20 - 13s - loss: 0.7189 - accuracy: 0.7318 - val_loss: 0.9540 - val_accuracy: 0.6378 - 13s/epoch - 665ms/step
# Epoch 46/150
# 20/20 - 13s - loss: 0.6801 - accuracy: 0.7318 - val_loss: 1.0067 - val_accuracy: 0.6378 - 13s/epoch - 670ms/step
# Epoch 47/150
# 20/20 - 13s - loss: 0.6271 - accuracy: 0.7659 - val_loss: 0.9785 - val_accuracy: 0.6865 - 13s/epoch - 667ms/step
# Epoch 48/150
# 20/20 - 13s - loss: 0.6300 - accuracy: 0.7614 - val_loss: 0.9441 - val_accuracy: 0.6432 - 13s/epoch - 670ms/step
# Epoch 49/150
# 20/20 - 14s - loss: 0.6331 - accuracy: 0.7614 - val_loss: 1.0044 - val_accuracy: 0.6757 - 14s/epoch - 684ms/step
# Epoch 50/150
# 20/20 - 15s - loss: 0.6550 - accuracy: 0.7477 - val_loss: 0.9878 - val_accuracy: 0.6649 - 15s/epoch - 731ms/step
# Epoch 51/150
# 20/20 - 13s - loss: 0.6979 - accuracy: 0.7432 - val_loss: 1.0055 - val_accuracy: 0.6757 - 13s/epoch - 665ms/step
# Epoch 52/150
# 20/20 - 13s - loss: 0.6514 - accuracy: 0.7682 - val_loss: 0.9693 - val_accuracy: 0.6595 - 13s/epoch - 668ms/step
# Epoch 53/150
# 20/20 - 13s - loss: 0.6381 - accuracy: 0.7568 - val_loss: 1.0021 - val_accuracy: 0.6432 - 13s/epoch - 663ms/step
# Epoch 54/150
# 20/20 - 13s - loss: 0.6335 - accuracy: 0.7636 - val_loss: 0.9932 - val_accuracy: 0.6649 - 13s/epoch - 664ms/step
# Epoch 55/150
# 20/20 - 13s - loss: 0.6650 - accuracy: 0.7273 - val_loss: 1.0154 - val_accuracy: 0.6595 - 13s/epoch - 672ms/step
# Epoch 56/150
# 20/20 - 13s - loss: 0.6869 - accuracy: 0.7159 - val_loss: 0.9565 - val_accuracy: 0.6919 - 13s/epoch - 666ms/step
# Epoch 57/150
# 20/20 - 16s - loss: 0.6294 - accuracy: 0.7659 - val_loss: 0.9147 - val_accuracy: 0.7081 - 16s/epoch - 815ms/step
# Epoch 58/150
# 20/20 - 14s - loss: 0.6117 - accuracy: 0.7614 - val_loss: 0.9576 - val_accuracy: 0.6973 - 14s/epoch - 709ms/step
# Epoch 59/150
# 20/20 - 15s - loss: 0.5939 - accuracy: 0.7750 - val_loss: 0.9422 - val_accuracy: 0.6541 - 15s/epoch - 733ms/step
# Epoch 60/150
# 20/20 - 13s - loss: 0.5486 - accuracy: 0.8068 - val_loss: 1.0026 - val_accuracy: 0.6378 - 13s/epoch - 669ms/step
# Epoch 61/150
# 20/20 - 14s - loss: 0.6446 - accuracy: 0.7386 - val_loss: 0.9792 - val_accuracy: 0.6649 - 14s/epoch - 677ms/step
# Epoch 62/150
# 20/20 - 14s - loss: 0.5703 - accuracy: 0.7841 - val_loss: 1.0144 - val_accuracy: 0.6270 - 14s/epoch - 678ms/step
# Epoch 63/150
# 20/20 - 13s - loss: 0.5923 - accuracy: 0.7636 - val_loss: 0.9717 - val_accuracy: 0.6703 - 13s/epoch - 667ms/step
# Epoch 64/150
# 20/20 - 13s - loss: 0.6227 - accuracy: 0.7727 - val_loss: 0.9402 - val_accuracy: 0.6865 - 13s/epoch - 666ms/step
# Epoch 65/150
# 20/20 - 13s - loss: 0.5641 - accuracy: 0.7841 - val_loss: 0.9348 - val_accuracy: 0.6649 - 13s/epoch - 661ms/step
# Epoch 66/150
# 20/20 - 13s - loss: 0.5640 - accuracy: 0.7841 - val_loss: 1.0397 - val_accuracy: 0.6270 - 13s/epoch - 665ms/step
# Epoch 67/150
# 20/20 - 15s - loss: 0.5859 - accuracy: 0.7864 - val_loss: 1.0525 - val_accuracy: 0.6486 - 15s/epoch - 726ms/step
# Epoch 68/150
# 20/20 - 13s - loss: 0.5727 - accuracy: 0.7795 - val_loss: 1.0113 - val_accuracy: 0.6649 - 13s/epoch - 672ms/step
# Epoch 69/150
# 20/20 - 13s - loss: 0.6194 - accuracy: 0.7909 - val_loss: 1.0301 - val_accuracy: 0.6324 - 13s/epoch - 667ms/step
# Epoch 70/150
# 20/20 - 13s - loss: 0.5716 - accuracy: 0.7614 - val_loss: 0.8872 - val_accuracy: 0.7027 - 13s/epoch - 666ms/step
# Epoch 71/150
# 20/20 - 14s - loss: 0.5955 - accuracy: 0.7705 - val_loss: 0.9392 - val_accuracy: 0.6865 - 14s/epoch - 677ms/step
# Epoch 72/150
# 20/20 - 13s - loss: 0.5970 - accuracy: 0.7932 - val_loss: 0.8916 - val_accuracy: 0.6703 - 13s/epoch - 673ms/step
# Epoch 73/150
# 20/20 - 13s - loss: 0.4996 - accuracy: 0.8500 - val_loss: 0.9159 - val_accuracy: 0.7081 - 13s/epoch - 663ms/step
# Epoch 74/150
# 20/20 - 13s - loss: 0.5753 - accuracy: 0.7659 - val_loss: 1.0317 - val_accuracy: 0.6378 - 13s/epoch - 673ms/step
# Epoch 75/150
# 20/20 - 13s - loss: 0.5457 - accuracy: 0.7727 - val_loss: 0.9853 - val_accuracy: 0.6811 - 13s/epoch - 663ms/step
# Epoch 76/150
# 20/20 - 13s - loss: 0.5856 - accuracy: 0.7841 - val_loss: 0.8938 - val_accuracy: 0.7027 - 13s/epoch - 667ms/step
# Epoch 77/150
# 20/20 - 13s - loss: 0.5499 - accuracy: 0.7795 - val_loss: 0.9241 - val_accuracy: 0.7027 - 13s/epoch - 666ms/step
# Epoch 78/150
# 20/20 - 13s - loss: 0.5645 - accuracy: 0.7864 - val_loss: 1.0055 - val_accuracy: 0.6541 - 13s/epoch - 661ms/step
# Epoch 79/150
# 20/20 - 14s - loss: 0.5234 - accuracy: 0.8114 - val_loss: 0.9731 - val_accuracy: 0.6811 - 14s/epoch - 700ms/step
# Epoch 80/150
# 20/20 - 14s - loss: 0.5165 - accuracy: 0.8000 - val_loss: 1.0236 - val_accuracy: 0.6703 - 14s/epoch - 695ms/step
# Epoch 81/150
# 20/20 - 16s - loss: 0.5311 - accuracy: 0.7886 - val_loss: 0.9236 - val_accuracy: 0.7189 - 16s/epoch - 804ms/step
# Epoch 82/150
# 20/20 - 14s - loss: 0.5236 - accuracy: 0.8000 - val_loss: 1.0227 - val_accuracy: 0.6378 - 14s/epoch - 694ms/step
# Epoch 83/150
# 20/20 - 13s - loss: 0.5571 - accuracy: 0.7886 - val_loss: 0.9918 - val_accuracy: 0.6595 - 13s/epoch - 670ms/step
# Epoch 84/150
# 20/20 - 13s - loss: 0.5048 - accuracy: 0.8341 - val_loss: 0.9760 - val_accuracy: 0.6919 - 13s/epoch - 670ms/step
# Epoch 85/150
# 20/20 - 13s - loss: 0.5560 - accuracy: 0.7909 - val_loss: 1.0103 - val_accuracy: 0.6811 - 13s/epoch - 668ms/step
# Epoch 86/150
# 20/20 - 13s - loss: 0.5416 - accuracy: 0.8091 - val_loss: 1.0017 - val_accuracy: 0.7135 - 13s/epoch - 672ms/step
# Epoch 87/150
# 20/20 - 13s - loss: 0.4905 - accuracy: 0.8068 - val_loss: 0.9753 - val_accuracy: 0.7189 - 13s/epoch - 671ms/step
# Epoch 88/150
# 20/20 - 14s - loss: 0.4920 - accuracy: 0.8250 - val_loss: 1.0381 - val_accuracy: 0.6865 - 14s/epoch - 676ms/step
# Epoch 89/150
# 20/20 - 15s - loss: 0.4910 - accuracy: 0.7795 - val_loss: 0.9441 - val_accuracy: 0.6757 - 15s/epoch - 735ms/step
# Epoch 90/150
# 20/20 - 13s - loss: 0.5019 - accuracy: 0.8273 - val_loss: 0.9842 - val_accuracy: 0.6919 - 13s/epoch - 672ms/step
# Epoch 91/150
# 20/20 - 13s - loss: 0.4722 - accuracy: 0.8114 - val_loss: 0.9383 - val_accuracy: 0.6919 - 13s/epoch - 670ms/step
# Epoch 92/150
# 20/20 - 13s - loss: 0.4942 - accuracy: 0.7955 - val_loss: 0.9359 - val_accuracy: 0.7135 - 13s/epoch - 669ms/step
# Epoch 93/150
# 20/20 - 14s - loss: 0.5160 - accuracy: 0.8023 - val_loss: 0.9754 - val_accuracy: 0.6865 - 14s/epoch - 679ms/step
# Epoch 94/150
# 20/20 - 14s - loss: 0.4856 - accuracy: 0.8432 - val_loss: 1.0069 - val_accuracy: 0.6865 - 14s/epoch - 681ms/step
# Epoch 95/150
# 20/20 - 13s - loss: 0.4780 - accuracy: 0.8159 - val_loss: 1.0030 - val_accuracy: 0.6757 - 13s/epoch - 672ms/step
# Epoch 96/150
# 20/20 - 13s - loss: 0.4709 - accuracy: 0.8136 - val_loss: 0.9368 - val_accuracy: 0.7135 - 13s/epoch - 668ms/step
# Epoch 97/150
# 20/20 - 16s - loss: 0.4950 - accuracy: 0.8000 - val_loss: 0.8925 - val_accuracy: 0.7297 - 16s/epoch - 809ms/step
# Epoch 98/150
# 20/20 - 14s - loss: 0.4589 - accuracy: 0.8205 - val_loss: 0.9790 - val_accuracy: 0.7081 - 14s/epoch - 710ms/step
# Epoch 99/150
# 20/20 - 15s - loss: 0.5514 - accuracy: 0.8023 - val_loss: 0.9501 - val_accuracy: 0.7081 - 15s/epoch - 743ms/step
# Epoch 100/150
# 20/20 - 14s - loss: 0.4427 - accuracy: 0.8273 - val_loss: 0.9552 - val_accuracy: 0.6703 - 14s/epoch - 677ms/step
# Epoch 101/150
# 20/20 - 13s - loss: 0.4919 - accuracy: 0.8136 - val_loss: 0.9241 - val_accuracy: 0.7081 - 13s/epoch - 671ms/step
# Epoch 102/150
# 20/20 - 13s - loss: 0.5111 - accuracy: 0.8295 - val_loss: 0.9534 - val_accuracy: 0.6865 - 13s/epoch - 672ms/step
# Epoch 103/150
# 20/20 - 13s - loss: 0.4778 - accuracy: 0.8250 - val_loss: 0.9284 - val_accuracy: 0.7189 - 13s/epoch - 674ms/step
# Epoch 104/150
# 20/20 - 13s - loss: 0.4747 - accuracy: 0.8159 - val_loss: 0.9426 - val_accuracy: 0.7081 - 13s/epoch - 670ms/step
# Epoch 105/150
# 20/20 - 13s - loss: 0.4748 - accuracy: 0.8295 - val_loss: 0.9884 - val_accuracy: 0.6973 - 13s/epoch - 669ms/step
# Epoch 106/150
# 20/20 - 13s - loss: 0.4602 - accuracy: 0.8227 - val_loss: 0.9685 - val_accuracy: 0.6973 - 13s/epoch - 666ms/step
# Epoch 107/150
# 20/20 - 15s - loss: 0.4404 - accuracy: 0.8386 - val_loss: 0.9742 - val_accuracy: 0.6649 - 15s/epoch - 732ms/step
# Epoch 108/150
# 20/20 - 13s - loss: 0.4512 - accuracy: 0.8227 - val_loss: 1.0580 - val_accuracy: 0.6703 - 13s/epoch - 674ms/step
# Epoch 109/150
# 20/20 - 14s - loss: 0.5170 - accuracy: 0.8227 - val_loss: 0.9057 - val_accuracy: 0.7027 - 14s/epoch - 679ms/step
# Epoch 110/150
# 20/20 - 13s - loss: 0.4621 - accuracy: 0.8409 - val_loss: 1.0687 - val_accuracy: 0.6595 - 13s/epoch - 671ms/step
# Epoch 111/150
# 20/20 - 13s - loss: 0.4385 - accuracy: 0.8455 - val_loss: 1.0344 - val_accuracy: 0.6919 - 13s/epoch - 672ms/step
# Epoch 112/150
# 20/20 - 13s - loss: 0.4792 - accuracy: 0.8341 - val_loss: 0.9566 - val_accuracy: 0.6973 - 13s/epoch - 671ms/step
# Epoch 113/150
# 20/20 - 13s - loss: 0.4984 - accuracy: 0.8295 - val_loss: 0.9040 - val_accuracy: 0.7135 - 13s/epoch - 670ms/step
# Epoch 114/150
# 20/20 - 13s - loss: 0.4153 - accuracy: 0.8409 - val_loss: 0.9013 - val_accuracy: 0.7081 - 13s/epoch - 674ms/step
# Epoch 115/150
# 20/20 - 13s - loss: 0.4285 - accuracy: 0.8477 - val_loss: 1.0169 - val_accuracy: 0.7027 - 13s/epoch - 672ms/step
# Epoch 116/150
# 20/20 - 14s - loss: 0.4438 - accuracy: 0.8341 - val_loss: 1.0363 - val_accuracy: 0.6703 - 14s/epoch - 677ms/step
# Epoch 117/150
# 20/20 - 13s - loss: 0.4260 - accuracy: 0.8386 - val_loss: 0.9388 - val_accuracy: 0.6919 - 13s/epoch - 671ms/step
# Epoch 118/150
# 20/20 - 15s - loss: 0.4396 - accuracy: 0.8364 - val_loss: 0.9745 - val_accuracy: 0.6919 - 15s/epoch - 733ms/step
# Epoch 119/150
# 20/20 - 13s - loss: 0.5077 - accuracy: 0.8068 - val_loss: 0.9369 - val_accuracy: 0.7027 - 13s/epoch - 663ms/step
# Epoch 120/150
# 20/20 - 13s - loss: 0.4318 - accuracy: 0.8545 - val_loss: 0.9704 - val_accuracy: 0.7027 - 13s/epoch - 665ms/step
# Epoch 121/150
# 20/20 - 16s - loss: 0.4347 - accuracy: 0.8409 - val_loss: 0.8393 - val_accuracy: 0.7568 - 16s/epoch - 802ms/step
# Epoch 122/150
# 20/20 - 14s - loss: 0.4478 - accuracy: 0.8455 - val_loss: 0.9284 - val_accuracy: 0.7135 - 14s/epoch - 703ms/step
# Epoch 123/150
# 20/20 - 13s - loss: 0.4381 - accuracy: 0.8136 - val_loss: 1.0478 - val_accuracy: 0.6757 - 13s/epoch - 674ms/step
# Epoch 124/150
# 20/20 - 13s - loss: 0.4524 - accuracy: 0.8273 - val_loss: 0.9654 - val_accuracy: 0.7243 - 13s/epoch - 672ms/step
# Epoch 125/150
# 20/20 - 13s - loss: 0.4006 - accuracy: 0.8545 - val_loss: 0.9197 - val_accuracy: 0.7351 - 13s/epoch - 671ms/step
# Epoch 126/150
# 20/20 - 13s - loss: 0.4217 - accuracy: 0.8568 - val_loss: 1.0267 - val_accuracy: 0.6703 - 13s/epoch - 666ms/step
# Epoch 127/150
# 20/20 - 13s - loss: 0.4274 - accuracy: 0.8523 - val_loss: 1.0194 - val_accuracy: 0.6811 - 13s/epoch - 665ms/step
# Epoch 128/150
# 20/20 - 15s - loss: 0.4046 - accuracy: 0.8364 - val_loss: 1.0561 - val_accuracy: 0.6919 - 15s/epoch - 731ms/step
# Epoch 129/150
# 20/20 - 13s - loss: 0.4506 - accuracy: 0.8250 - val_loss: 0.9931 - val_accuracy: 0.6649 - 13s/epoch - 663ms/step
# Epoch 130/150
# 20/20 - 13s - loss: 0.4059 - accuracy: 0.8545 - val_loss: 1.0944 - val_accuracy: 0.6432 - 13s/epoch - 665ms/step
# Epoch 131/150
# 20/20 - 13s - loss: 0.4155 - accuracy: 0.8545 - val_loss: 0.9622 - val_accuracy: 0.6973 - 13s/epoch - 662ms/step
# Epoch 132/150
# 20/20 - 13s - loss: 0.3995 - accuracy: 0.8750 - val_loss: 0.9466 - val_accuracy: 0.6973 - 13s/epoch - 660ms/step
# Epoch 133/150
# 20/20 - 13s - loss: 0.4288 - accuracy: 0.8432 - val_loss: 1.0227 - val_accuracy: 0.6973 - 13s/epoch - 667ms/step
# Epoch 134/150
# 20/20 - 14s - loss: 0.4775 - accuracy: 0.8295 - val_loss: 0.9563 - val_accuracy: 0.6919 - 14s/epoch - 676ms/step
# Epoch 135/150
# 20/20 - 13s - loss: 0.4045 - accuracy: 0.8705 - val_loss: 0.9459 - val_accuracy: 0.6757 - 13s/epoch - 666ms/step
# Epoch 136/150
# 20/20 - 15s - loss: 0.4161 - accuracy: 0.8477 - val_loss: 0.9426 - val_accuracy: 0.6919 - 15s/epoch - 743ms/step
# Epoch 137/150
# 20/20 - 13s - loss: 0.3620 - accuracy: 0.8705 - val_loss: 0.9676 - val_accuracy: 0.7297 - 13s/epoch - 667ms/step
# Epoch 138/150
# 20/20 - 13s - loss: 0.4132 - accuracy: 0.8432 - val_loss: 0.9747 - val_accuracy: 0.6811 - 13s/epoch - 674ms/step
# Epoch 139/150
# 20/20 - 14s - loss: 0.4286 - accuracy: 0.8455 - val_loss: 0.9910 - val_accuracy: 0.6865 - 14s/epoch - 676ms/step
# Epoch 140/150
# 20/20 - 13s - loss: 0.4303 - accuracy: 0.8318 - val_loss: 1.0663 - val_accuracy: 0.6541 - 13s/epoch - 668ms/step
# Epoch 141/150
# 20/20 - 13s - loss: 0.3909 - accuracy: 0.8523 - val_loss: 1.0172 - val_accuracy: 0.6973 - 13s/epoch - 662ms/step
# Epoch 142/150
# 20/20 - 13s - loss: 0.4250 - accuracy: 0.8455 - val_loss: 1.0147 - val_accuracy: 0.6865 - 13s/epoch - 659ms/step
# Epoch 143/150
# 20/20 - 13s - loss: 0.4120 - accuracy: 0.8432 - val_loss: 0.9518 - val_accuracy: 0.6865 - 13s/epoch - 658ms/step
# Epoch 144/150
# 20/20 - 13s - loss: 0.4478 - accuracy: 0.8568 - val_loss: 0.9531 - val_accuracy: 0.7297 - 13s/epoch - 656ms/step
# Epoch 145/150
# 20/20 - 13s - loss: 0.4019 - accuracy: 0.8682 - val_loss: 0.9899 - val_accuracy: 0.6811 - 13s/epoch - 654ms/step
# Epoch 146/150
# 20/20 - 13s - loss: 0.4336 - accuracy: 0.8455 - val_loss: 0.9748 - val_accuracy: 0.7081 - 13s/epoch - 653ms/step
# Epoch 147/150
# 20/20 - 13s - loss: 0.3849 - accuracy: 0.8682 - val_loss: 0.9394 - val_accuracy: 0.6703 - 13s/epoch - 656ms/step
# Epoch 148/150
# 20/20 - 14s - loss: 0.4079 - accuracy: 0.8364 - val_loss: 1.0002 - val_accuracy: 0.6649 - 14s/epoch - 718ms/step
# Epoch 149/150
# 20/20 - 13s - loss: 0.3791 - accuracy: 0.8636 - val_loss: 0.9763 - val_accuracy: 0.6757 - 13s/epoch - 661ms/step
# Epoch 150/150
# 20/20 - 13s - loss: 0.3611 - accuracy: 0.8705 - val_loss: 0.9470 - val_accuracy: 0.6757 - 13s/epoch - 651ms/step

# %%
#Plot Training

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training Model', 'Validation Model'], loc='upper right')
plt.title('Nilai loss pada tiap epoch')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training Model', 'Validation Model'], loc='upper right')
plt.title('Nilai akurasi pada tiap epoch')
plt.show()

# %% [markdown]
# ### **Testing Model Prediction**

# %%
model = load_model("/content/drive/MyDrive/FinalModelML.h5")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 5, 5, 1536)       54336736
#  onal)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 128)               196736
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 54,534,117
# Trainable params: 197,381
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
labels = sorted(os.listdir("/content/drive/MyDrive/DATA 5/train"))
print(labels)
# Out:
# ['Acnee', 'Actinic Keratosis', 'Basal Cell Carcinoma', 'Eczemaa', 'Rosacea']

# %%
#Testing
from keras.preprocessing import image
from google.colab import files

uploade = files.upload()

for ft in uploade.keys():

  pathtest = ft
  img = image.load_img(pathtest, target_size= (224, 224))
  imagplot = plt.imshow(img)
  xtest = image.img_to_array(img)
  xtest = np.expand_dims(xtest, axis=0)

  file_image = np.vstack([xtest])
  prediction_class = model_image.predict(file_image, batch_size=10)
  print(ft)

  output = prediction_class[0].argmax()
  print("The image is classified as:",labels[output])

  break
# Out:
#      <input type="file" id="files-1f7c2c9d-ff1a-4cfa-8610-48939c79170b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f7c2c9d-ff1a-4cfa-8610-48939c79170b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving eczema.8.jpg to eczema.8.jpg
# eczema.8.jpg
# The image is classified as: Eczemaa

# %%
#Testing tanpa upload foto
from keras.preprocessing import image

path = '/content/drive/MyDrive/DATA 5/testing/Eczemaa/eczema.14.jpg'
img = image.load_img(path, target_size=(224,224,3))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
images = np.vstack([x])
plt.imshow(img)
img = np.expand_dims(img, axis = 0)
predictions = model.predict(img)
print("The image is classified as", predictions[0])
predicted_class = labels[np.argmax(predictions[0])]
print("Prediction for the image below:", predicted_class)
# Out:
# The image is classified as [0. 0. 0. 1. 0.]
# Prediction for the image below: Eczemaa
